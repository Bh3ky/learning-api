# %% [markdown]
# ## API Deployment to Cloud
#
# * cloud is an informal term used to refer to a collection of computer servers and connection of infrastructure for the public internet.
#
#
# Benefits of Cloud Deployment
#
#     1. opportunity to learn the end-to-end process of cloud deployment, development, and operations.
